# %%
df
# Out:
#                         Biomass_UUID_01 Biomass_ID biomass_no.  \
# 0    5C959E49-831F-7372-533E-3CBC36204C      bm-01           1
# 1    BA71DA85-EC2D-4BB5-FBED-64DAEAE74A      bm-02           2
# 2    ED8CB80C-0756-2A34-DFC0-7D2EE7DE24      bm-03           3
# 3    F869EA13-8B85-3244-9AEF-D446D1E9CE      bm-04           4
# 4    4BAFFC5E-900F-2A34-2000-9F290BD28C      bm-05           5
# ..                                  ...        ...         ...
# 241
# 242
# 243
# 244
# 245
#
#     Source_codename  Material_type Sample_code             Primary_crop  \
# 0           Oakleaf  Tomato pomace        TmPm  Tomatoes for processing
# 1         Pinecrest  Tomato pomace        TmPm  Tomatoes for processing
# 2        Riverstone  Tomato pomace        TmPm  Tomatoes for processing
# 3         Maplewood   Grape pomace        GpPm                   Grapes
# 4         Maplewood     Grape stem        GpSt                   Grapes
# ...

# %%
primary_product_name = df.Primary_crop.unique()

print(primary_product_name)

primary_product_df = pd.DataFrame(primary_product_name, columns=["Primary_crop"])
# Out:
# ['Tomatoes for processing' 'Grapes' 'Almonds' 'Walnuts' 'Sweet potatoes'
#  'Algae' 'Olives - processing' 'Corn - all' 'Hay - alfalfa'
#  'Silage - wheat' 'Rice' 'Peaches' 'Potatoes' 'Cucumbers and pickles' '']

# %%
primary_product_df
# Out:
#                Primary_crop
# 0   Tomatoes for processing
# 1                    Grapes
# 2                   Almonds
# 3                   Walnuts
# 4            Sweet potatoes
# 5                     Algae
# 6       Olives - processing
# 7                Corn - all
# 8             Hay - alfalfa
# 9            Silage - wheat
# 10                     Rice
# 11                  Peaches
# 12                 Potatoes
# 13    Cucumbers and pickles
# 14

# %%
basic_sample_info_df.Material_type.unique()
# Out:
# array(['Tomato pomace', 'Grape pomace', 'Grape stem', 'Spent yeast',
#        'Spent oak chips', 'Unused oak stick', 'Lees', 'Almond Shells',
#        'Almond Hulls', 'Almond Branches', 'Almond Shells and Hulls mix',
#        'Walnut Shells', 'Walnut Hulls', 'Walnut tree sticks',
#        'Almond woodchips', 'Sweet potato culls', 'Sargassum',
#        'Olive pomace', 'Olive stem', 'Corn stover husks',
#        'Corn stover cobs', 'Corn stover stalks', 'Alfalfa', 'Wheat straw',
#        'Rice straw', 'Peach seeds', 'Peach pomace',
#        'Peach screening waste', 'Peach stems / leaves',
#        'Potato culls-red', 'Potato culls-white', 'Potato culls-yellow',
#        'Cucumber culls', 'Spent oak stick', ''], dtype=object)

# %%
# Step 1: Import the function from your script
# Since gsheet_to_pandas.py is in the same directory, you can import it directly.
from gsheet_to_pandas import gsheet_to_df

# Step 2: Define your sheet details
GSHEET_NAME = "Aim 1-Feedstock Collection and Processing Data-BioCirV"
WORKSHEET_NAME = "02-Preprocessing"
CREDENTIALS_PATH = "credentials.json"

# Step 3: Call the function to get the DataFrame
# This creates the 'df' variable inside this notebook
prepro_df = gsheet_to_df(GSHEET_NAME, WORKSHEET_NAME, CREDENTIALS_PATH)

# %%
prepro_df.head()
# Out:
#                        Prepro_UUID_02 Prepro_ID  Material_type Sample_name  \
# 0  F30C220E-637C-CF3B-C39D-D95DE57164   PreP_01  Tomato pomace  Oak-TmPm01
# 1  CF86943B-BD98-CC2D-D337-B30CB1AA85   PreP_02  Tomato pomace  Oak-TmPm01
# 2  4D584CFD-AF8D-0F97-BFE6-682E1A3308   PreP_03  Tomato pomace  Oak-TmPm01
# 3  00D6D902-B934-5D99-F8C2-1EC6D59973   PreP_04  Tomato pomace  Oak-TmPm01
# 4  8FE4BD54-C63E-CB01-A003-931E7467D2   PreP_05  Tomato pomace  Pin-TmPm02
#
#   Source_codename Prepro_method Prepro_material_name       Storage_cond  \
# 0         Oakleaf    Freeze Dry     Oak-TmPm01FD(64)          Room Temp
# 1         Oakleaf      Oven dry      Oak-TmPm01O(85)   RT vacuum sealed
# 2         Oakleaf        Freeze      Oak-TmPm01F(08)  Frozen vac sealed
# 3         Oakleaf         As Is      Oak-TmPm01A(73)                 4C
# 4       Pinecrest    Freeze Dry     Pin-TmPm02FD(D2)   RT vacuum sealed
#
#   Prepro_temp_C Amount_before_drying_g  ... Analyze_status Prox_prepro_count  \
# ...

# %%
test_object = prepro_df[["Prepro_material_name", "Material_type"]]

test_object.head()
# Out:
#   Prepro_material_name  Material_type
# 0     Oak-TmPm01FD(64)  Tomato pomace
# 1      Oak-TmPm01O(85)  Tomato pomace
# 2      Oak-TmPm01F(08)  Tomato pomace
# 3      Oak-TmPm01A(73)  Tomato pomace
# 4     Pin-TmPm02FD(D2)  Tomato pomace

# %%
prepro_methods = prepro_df["Prepro_method"].unique()

# %%
import pandas as pd

prepro_df = pd.DataFrame(prepro_methods, columns=["Prepro_method"])

# %%
from sqlmodel import Session
from my_etl_project.src.database import engine
from my_etl_project.src.models.sample_preprocessing import PreprocessingMethod

def insert_preprocessing_method():
    with Session(engine) as session:
        pre = User(name="John Doe", fullname="John Doe", nickname="Johnny")
        session.add(user)
        session.commit()

if __name__ == "__main__":
    insert_user()

# %%
preprro_abbreviations = {
